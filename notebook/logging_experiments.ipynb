# %% [markdown]
# ## Logging related experiments

# %%
print("ok")
# Out:
# ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE=f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '2025-07-26_14-58-59.log'

# %%
LOG_FILE = os.path.join(logs_dir, LOG_FILE)

# %%
LOG_FILE
# Out:
# '/Users/kicky/LLMOPS/projects/project1/document_portal/notebook/logs/2025-07-26_14-58-59.log'

# %%
logging.basicConfig(
    filename=LOG_FILE,
    format="[%(asctime)s] %(levelname)s %(name)s (line:%(lineno)d) -  %(message)s",
    level=logging.INFO,
)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("Logging setup complete.")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Structlog
# Used if you want to structure the logs or messages in some json or yaml or any other formats
# Most commonly used for json formatting

# %%
import structlog
logs = structlog.get_logger()

# %%
logs.info("Logging setup complete with structlog.")
# Out:
# 2025-07-26 16:28:33 [info     ] Logging setup complete with structlog.
